# %% [markdown]
# ## plotting
#
# @author: j-huthmacher
#
# For quickly visualize whatever you need.

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# ## 29.06.2020

# %%
fig, ax = plt.subplots(figsize=(10,5))

rewards = pd.read_csv(r"C:\Users\email\Documents\LMU\4_Semester\ASP\Project\AlphaWorm\.results\2020-06-29\DPPG-WormDomain-8-FixedParameter\best_agent\rewards.csv").iloc[::2, :]

import json
from pprint import pprint

with open(r"C:\Users\email\Documents\LMU\4_Semester\ASP\Project\AlphaWorm\.results\2020-06-29\DPPG-WormDomain-8-FixedParameter\best_agent\DPPG-WormDomain-8-FixedParameter_best_params.json") as json_file:
    pprint(json.load(json_file))

rewards["reward"].plot(ax=ax)
# Out:
# {'actor_lr': 0.001,
#  'batch_size': 512,
#  'critic_lr': 0.001,
#  'episodes': 2000,
#  'explore_threshold': 0.5,
#  'gamma': 0.999,
#  'n_layers': 2,
#  'n_units_l0': 128,
#  'n_units_l1': 128,
#  'tau': 0.001,
#  'training_steps': 1000}

# %% [markdown]
# ---

# %% [markdown]
# ## 50% Exploration Run

# %%
fig, ax = plt.subplots(figsize=(10,5))

rewards = pd.read_csv(r"C:\Users\email\Documents\LMU\4_Semester\ASP\Project\AlphaWorm\.results\2020-07-01\best_agent\rewards.csv").iloc[::2, :]

import json
from pprint import pprint

with open(r"C:\Users\email\Documents\LMU\4_Semester\ASP\Project\AlphaWorm\.results\2020-07-01\best_agent\DPPG-WormDomain-8-FixedParameter_best_params.json") as json_file:
    pprint(json.load(json_file))



rewards["reward"].plot(ax=ax)
# Out:
# {'actor_lr': 0.001,
#  'batch_size': 512,
#  'critic_lr': 0.001,
#  'episodes': 2000,
#  'explore_threshold': 0.5,
#  'gamma': 0.999,
#  'n_layers': 2,
#  'n_units_l0': 128,
#  'n_units_l1': 128,
#  'tau': 0.001,
#  'training_steps': 1000}

# %% [markdown]
# ---

# %%
# Overall rewards - Trainings run 26.06 - 27.06
fig, ax = plt.subplots(figsize=(15,10))

rewards = pd.read_csv(r"C:\Users\email\Documents\LMU\4_Semester\ASP\Project\AlphaWorm\.results\2020-06-28\HPO-Results\best_agent\rewards.csv")
rewards["reward"].plot(ax=ax)

# %%
episodes = [
    "Episode 0",
    "Episode 1",
    "Episode 2",
    "Episode 3",
    "Episode 4",
    "Episode 5",
    "Episode 6",
    "Episode 7",
    "Episode 8",
    "Episode 9",
    "Episode 10",
]

fig, ax = plt.subplots(figsize=(15,10))

rewards_episode = pd.read_csv(r"C:\Users\email\Documents\LMU\4_Semester\ASP\Project\AlphaWorm\.results\2020-06-28\HPO-Results\best_agent\trainings_rewards.csv")

rewards_episode[episodes].plot(ax = ax)
ax.legend()

# %%
fig, ax = plt.subplots(figsize=(15,10))

rewards_episode = pd.read_csv(r"C:\Users\email\Documents\LMU\4_Semester\ASP\Project\AlphaWorm\dev\models\2020-06-26\WormDomain-5_Local\best_agent\trainings_rewards.csv").drop('Unnamed: 0', 1)

rewards_episode.plot(ax = ax)
ax.legend()

# %% [markdown]
# ## Training 28.06.2020 - Local

# %%
import pandas as pd 
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(15,10))

rewards_episode = pd.read_csv(r"C:\Users\email\Documents\LMU\4_Semester\ASP\Project\AlphaWorm\dev\models\2020-06-28\DPPG-WormDomain-7-Local\0_DPPG-WormDomain-7-Local\results\trainings_rewards.csv").drop('Unnamed: 0', 1)

rewards_episode[rewards_episode.columns[:3]].plot(ax= ax)

# %%
fig, ax = plt.subplots(figsize=(15,10))

rewards = pd.read_csv(r"C:\Users\email\Documents\LMU\4_Semester\ASP\Project\AlphaWorm\dev\models\2020-06-28\DPPG-WormDomain-7-Local\0_DPPG-WormDomain-7-Local\results\rewards.csv").iloc[::2, :]


rewards["reward"].plot( ax= ax)

# %%
rewards
# Out:
#          reward  episode
# 0     -7.293527    999.0
# 0      0.000000      NaN
# 1      3.533302    999.0
# 0      1.000000      NaN
# 2     -1.882433    999.0
# ..          ...      ...
# 0    138.000000      NaN
# 139   -8.894197    999.0
# 0    139.000000      NaN
# 140   -0.049783    999.0
# 0    140.000000      NaN
#
# [282 rows x 2 columns]
